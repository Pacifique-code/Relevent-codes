# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading daily data

# %%
data = pd.read_csv("/home/pbatungwanay/Bureau/MODIS_NDVI_NEB.csv", index_col=[0], parse_dates=True)
data.head()
# Out:
#                     NDVI  NDVI1
# system:time_start
# 2000-02-24         0.413  0.396
# 2000-02-25         0.413  0.396
# 2000-02-26         0.487  0.479
# 2000-02-27         0.453  0.442
# 2000-02-28         0.453  0.442

# %% [markdown]
# changing to monthly mean

# %%
Montlyndvi = data.resample('MS').mean()

# %%
Montlyndvi
# Out:
#                        NDVI     NDVI1
# system:time_start
# 2000-02-01         0.445333  0.432833
# 2000-03-01         0.500161  0.492452
# 2000-04-01         0.594267  0.587500
# 2000-05-01         0.611613  0.609097
# 2000-06-01         0.503500  0.501067
# ...                     ...       ...
# 2018-08-01         0.458806  0.456226
# 2018-09-01         0.469400  0.467633
# 2018-10-01         0.473645  0.471968
# 2018-11-01         0.554300  0.548367
# 2018-12-01         0.678200  0.674900
#
# [227 rows x 2 columns]

# %%
Montlyndvi.to_csv(r'/home/pbatungwanay/Bureau/Montlyndvi.csv', index =True )

# %% [markdown]
# # Data arrangement in monthly mean format for all 18 years

# %%
Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 
         'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
#create list for made up average ndvi for NDVI data %
NEB_NDVI_mean = [0.592028464705882,0.548957405555556,0.565718622222222,0.623394438888889,0.644336927777778,0.58870065,0.496820788888889,0.435765227777778,0.424811105555556,0.469063211111111,0.582755555555556,0.637980294444444
]

# %%
ndvi_data = {'Month': Month, 'NEB_NDVI_mean': NEB_NDVI_mean}

# %%
df = pd.DataFrame(ndvi_data)

# %%
df[:12]
# Out:
#    Month  NEB_NDVI_mean
# 0    Jan       0.592028
# 1    Feb       0.548957
# 2    Mar       0.565719
# 3    Apr       0.623394
# 4    May       0.644337
# 5   June       0.588701
# 6   July       0.496821
# 7    Aug       0.435765
# 8    Sep       0.424811
# 9    Oct       0.469063
# 10   Nov       0.582756
# 11   Dec       0.637980

# %%
sns.lineplot(x='Month', y='NEB_NDVI_mean', data=df, sort=False)

plt.xlabel(' ')
plt.ylabel('NDVI mean',fontsize=16)
plt.legend(['NDVI'], loc=4)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.savefig('/home/pbatungwanay/Bureau/ndvi_cycle_NEB.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Comparing precipitation with NDVI for Kirundo

# %%
#create list of months
Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 
         'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
#create list for made up average percipitation for kirundo observed data %
Kirundo_obs_pre = [81.941 ,98.725 ,136.191 ,184.609 ,100.122 ,16.547 ,7.122 ,22.688 ,70.772 ,114.178 ,127.041 ,92.516 
]
#create list for made up average percipitation for muyinga observed data %
Muyinga_obs_prec = [110.113 ,110.003 ,157.448 ,180.673 ,74.244 ,14.800 ,1.572 ,17.003 ,54.431 ,106.178 ,144.219 ,127.375 
]

Kirundo_chirps_pre = [90.127 ,88.764 ,141.583 ,170.743 ,93.503 ,12.713 ,3.358 ,21.957 ,58.496 ,114.576 ,141.455,103.487 ]

Muyinga_chirps_prec = [110.873 ,99.919 ,146.244,171.013 ,84.084 ,6.595 ,1.700,14.823,52.508,109.087,140.261,123.473 
 ]

Kirundo_ERA5_pre = [89.469 ,87.688 ,129.938,174.125,94.188,13.781,3.688,19.125,61.813,128.375,156.750,114.844]

Muyinga_ERA5_prec = [132.219,122.813,178.375,204.594 ,99.844,12.125,3.156,17.500,64.594,148.750,193.313,162.125 
 
 ]
NEB_NDVI_mean = [0.592028464705882,0.548957405555556,0.565718622222222,0.623394438888889,0.644336927777778,0.58870065,0.496820788888889,0.435765227777778,0.424811105555556,0.469063211111111,0.582755555555556,0.637980294444444
]

#assign lists to a value
data = {'Month': Month, 'Kirundo_obs_pre': Kirundo_obs_pre, 'Muyinga_obs_prec': Muyinga_obs_prec, 'Kirundo_chirps_pre':Kirundo_chirps_pre,
       'Muyinga_chirps_prec': Muyinga_chirps_prec,'Kirundo_ERA5_pre':Kirundo_ERA5_pre,'Muyinga_ERA5_prec':Muyinga_ERA5_prec , 'NEB_NDVI_mean':NEB_NDVI_mean}
#convert dictionary to a dataframe
df = pd.DataFrame(data)
#Print out all rows
df[:12]
# Out:
#    Month  Kirundo_obs_pre  Muyinga_obs_prec  Kirundo_chirps_pre  \
# 0    Jan           81.941           110.113              90.127
# 1    Feb           98.725           110.003              88.764
# 2    Mar          136.191           157.448             141.583
# 3    Apr          184.609           180.673             170.743
# 4    May          100.122            74.244              93.503
# 5   June           16.547            14.800              12.713
# 6   July            7.122             1.572               3.358
# 7    Aug           22.688            17.003              21.957
# 8    Sep           70.772            54.431              58.496
# 9    Oct          114.178           106.178             114.576
# 10   Nov          127.041           144.219             141.455
# 11   Dec           92.516           127.375             103.487
#
#     Muyinga_chirps_prec  Kirundo_ERA5_pre  Muyinga_ERA5_prec  NEB_NDVI_mean
# 0               110.873            89.469            132.219       0.592028
# 1                99.919            87.688            122.813       0.548957
# 2               146.244           129.938            178.375       0.565719
# 3               171.013           174.125            204.594       0.623394
# 4                84.084            94.188             99.844       0.644337
# 5                 6.595            13.781             12.125       0.588701
# 6                 1.700             3.688              3.156       0.496821
# 7                14.823            19.125             17.500       0.435765
# 8                52.508            61.813             64.594       0.424811
# 9               109.087           128.375            148.750       0.469063
# 10              140.261           156.750            193.313       0.582756
# 11              123.473           114.844            162.125       0.637980

# %%
# create line plot for average percipitation levels (Kirundo)
#plt.title('Average Percipitation Percentage by Month')
#sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.lineplot(x='Month', y='Kirundo_obs_pre', data=df, sort=False)
sns.lineplot(x='Month', y='Kirundo_chirps_pre', data=df, sort=False)
sns.lineplot(x='Month', y='Kirundo_ERA5_pre', data=df, sort=False)
plt.ylabel('Rainfall (mm)',fontsize=16)
plt.yticks(rotation=90)

plt.legend(['OBS', 'CHIRPS','ERA5'], loc=3)
plt.twinx()
sns.lineplot(x='Month', y='NEB_NDVI_mean', data=df, sort=False, color = 'black')
plt.yticks(rotation=90)
plt.xlabel(' ')
plt.ylabel('NDVI mean',fontsize=16)
plt.legend(['NDVI'], loc=4)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.savefig('/home/pbatungwanay/Bureau/precip_cycle_kirundo.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Comparing precipitation with NDVI for Muyinga

# %%
#plt.figure(figsize=(12,8))
# create line plot for average percipitation levels (Muyinga)
#plt.title('Average Percipitation Percentage by Month')
sns.lineplot(x='Month', y='Muyinga_obs_prec', data=df, sort=False)
sns.lineplot(x='Month', y='Muyinga_chirps_prec', data=df, sort=False)
sns.lineplot(x='Month', y='Muyinga_ERA5_prec', data=df, sort=False)
plt.ylabel('Rainfall (mm)',fontsize=16)
plt.yticks(rotation=90)

plt.legend(['OBS', 'CHIRPS','ERA5'], loc=3)
plt.twinx()
sns.lineplot(x='Month', y='NEB_NDVI_mean', data=df, sort=False, color = 'black')
plt.yticks(rotation=90)
plt.xlabel(' ')
plt.ylabel('NDVI mean',fontsize=16)
plt.legend(['NDVI'], loc=4)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.savefig('/home/pbatungwanay/Bureau/precip_cycle_muyinga.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
