# %%
setwd("~/Bureau")

# %% [markdown]
# Reading yearly data for climatic variables and NDVI

# %%
Data = read.csv('Yearly_NEB_data2.csv')

# %%
Data
# Out:
#    Date       CHIRPS_prec maximum_2m_air_temperature mean_2m_air_temperature
# 1  2000-12-31  872.987    26.23314                   20.72773
# 2  2001-12-31 1197.093    25.54445                   20.16692
# 3  2002-12-31 1096.508    26.11387                   20.67847
# 4  2003-12-31  953.476    26.28303                   20.92128
# 5  2004-12-31 1105.053    26.24772                   20.98672
# 6  2005-12-31  891.839    26.47506                   21.16706
# 7  2006-12-31 1232.525    26.06240                   20.79690
# 8  2007-12-31 1031.524    25.93627                   20.63964
# 9  2008-12-31  882.023    25.93370                   20.54319
# 10 2009-12-31 1073.191    26.17513                   20.84658
# 11 2010-12-31 1106.786    26.69195                   21.30909
# 12 2011-12-31 1103.046    25.84863                   20.50032
# 13 2012-12-31 1069.772    25.98104                   20.63772
# 14 2013-12-31 1162.515    26.38900                   21.02000
# ...

# %%
fit
# Out:
# Call:
# lm(formula = Data$NDVI ~ Year)
#
# Coefficients:
# (Intercept)         Year
#  -1.1655759    0.0008544
